# %%
from raptor_functions import raptor_data

# %%
from raptor_data import load_validated_breath_dataset

# %%
load_validated_breath_dataset()
# Out:
#      unique_id exp_name  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0            0      39A        0.0   316.594   315.854   315.735   313.180
# 1            0      39A        1.0   316.928   315.854   316.188   313.324
# 2            0      39A        2.0   315.711   316.045   315.759   313.514
# 3            0      39A        3.0   316.499   315.854   315.329   312.536
# 4            0      39A        4.0   317.048   315.568   315.520   312.679
# ..         ...      ...        ...       ...       ...       ...       ...
# 148        137      57b      148.0   316.236   316.021   316.021   313.514
# 149        137      57b      149.0   316.833   315.902   316.403   313.777
# 150        137      57b      150.0   316.714   316.188   315.973   313.801
# 151        137      57b      151.0   316.809   315.711   315.615   313.968
# 152        137      57b      152.0   316.117   315.997   315.973   313.705
#
# ...

# %%
from raptor_data import load_data

# %%
load_data()
# Out:
#      unique_id exp_name  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0            0      39A        0.0   316.594   315.854   315.735   313.180
# 1            0      39A        1.0   316.928   315.854   316.188   313.324
# 2            0      39A        2.0   315.711   316.045   315.759   313.514
# 3            0      39A        3.0   316.499   315.854   315.329   312.536
# 4            0      39A        4.0   317.048   315.568   315.520   312.679
# ..         ...      ...        ...       ...       ...       ...       ...
# 148        137      57b      148.0   316.236   316.021   316.021   313.514
# 149        137      57b      149.0   316.833   315.902   316.403   313.777
# 150        137      57b      150.0   316.714   316.188   315.973   313.801
# 151        137      57b      151.0   316.809   315.711   315.615   313.968
# 152        137      57b      152.0   316.117   315.997   315.973   313.705
#
# ...

# %%
from pathlib import Path
from subprocess import check_output

# %%
 if not Path('../pyproject.toml').exists():
        raise Exception(f"Cannot find a `pyproject.toml` file in the current folder: {Path().resolve()}")
project_name, version = check_output(("poetry", "version")).strip().decode().split(' ')
print(version)
# Out:
# 0.0.4

# %%
# pip install raptor_functions
from raptor_data import load_validated_breath_dataset
df = load_validated_breath_dataset()
df.head()
# Out:
#    unique_id exp_name  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0          0      39A        0.0   316.594   315.854   315.735   313.180
# 1          0      39A        1.0   316.928   315.854   316.188   313.324
# 2          0      39A        2.0   315.711   316.045   315.759   313.514
# 3          0      39A        3.0   316.499   315.854   315.329   312.536
# 4          0      39A        4.0   317.048   315.568   315.520   312.679
#
#    sensor_5  sensor_6  sensor_7  ...  sensor_22  sensor_23  sensor_24  \
# 0   307.498   315.926   316.188  ...    103.786    103.404    103.691
# 1   307.331   315.997   316.499  ...    103.882    103.357    103.595
# 2   307.403   315.950   315.926  ...    104.001    103.452    103.643
# 3   308.095   315.854   316.403  ...    104.073    103.380    103.619
# 4   307.188   315.926   316.451  ...    103.929    103.357    103.428
#
#    humidity  measurement_stage    date_exp  time_elapsed  \
# ...

# %%
from raptor_function import load_validated_breath_dataset
df = load_validated_breath_dataset()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3689391/890360511.py in <module>
# ----> 1 from raptor_function import load_validated_breath_dataset
#       2 df = load_validated_breath_dataset()
#
# ModuleNotFoundError: No module named 'raptor_function'

# %%
df
# Out:
#      unique_id exp_name  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0            0      39A        0.0   316.594   315.854   315.735   313.180
# 1            0      39A        1.0   316.928   315.854   316.188   313.324
# 2            0      39A        2.0   315.711   316.045   315.759   313.514
# 3            0      39A        3.0   316.499   315.854   315.329   312.536
# 4            0      39A        4.0   317.048   315.568   315.520   312.679
# ..         ...      ...        ...       ...       ...       ...       ...
# 148        137      57b      148.0   316.236   316.021   316.021   313.514
# 149        137      57b      149.0   316.833   315.902   316.403   313.777
# 150        137      57b      150.0   316.714   316.188   315.973   313.801
# 151        137      57b      151.0   316.809   315.711   315.615   313.968
# 152        137      57b      152.0   316.117   315.997   315.973   313.705
#
# ...

# %%
import pandas as pd
url = 'https://drive.google.com/file/d/1LUBsw5nIW_VSDGucxeudCrzDy4ntC1gW/view?usp=sharing'
# url='https://drive.google.com/file/d/0B6GhBwm5vaB2ekdlZW5WZnppb28/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url, index_col=0)

# %%
df
# Out:
#      unique_id exp_name  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0            0      39A        0.0   316.594   315.854   315.735   313.180
# 1            0      39A        1.0   316.928   315.854   316.188   313.324
# 2            0      39A        2.0   315.711   316.045   315.759   313.514
# 3            0      39A        3.0   316.499   315.854   315.329   312.536
# 4            0      39A        4.0   317.048   315.568   315.520   312.679
# ..         ...      ...        ...       ...       ...       ...       ...
# 148        137      57b      148.0   316.236   316.021   316.021   313.514
# 149        137      57b      149.0   316.833   315.902   316.403   313.777
# 150        137      57b      150.0   316.714   316.188   315.973   313.801
# 151        137      57b      151.0   316.809   315.711   315.615   313.968
# 152        137      57b      152.0   316.117   315.997   315.973   313.705
#
# ...

# %%
from datasets import get_data
